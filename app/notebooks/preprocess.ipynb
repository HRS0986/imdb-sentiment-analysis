# %%
from datasets import load_dataset

dataset = load_dataset("ajaykarthick/imdb-movie-reviews")
dataset.keys()
# Out:
# Using the latest cached version of the dataset since ajaykarthick/imdb-movie-reviews couldn't be found on the Hugging Face Hub
# Found the latest cached dataset configuration 'default' at C:\Users\hesha\.cache\huggingface\datasets\ajaykarthick___imdb-movie-reviews\default\0.0.0\2537b681735c256a7ab829666b118e03c3eb9e0a (last modified on Wed Mar 13 19:40:41 2024).
# dict_keys(['train', 'test'])

# %%
import pandas as pd
df = pd.DataFrame(dataset["train"])
df.drop(df.tail(20000).index, inplace = True)
df.shape
# Out:
# (20000, 2)

# %%
import re

# %%
df["review"] = df["review"].str.lower()
xx = "if you are 10 years old and never seen a movie before, maybe this film may be entertainment for you, but if you've seen several movies, this one will be a silly fully-cliched cheap and predictable for you. don't waste your time with this."
xx = xx.lower()
xx
# Out:
# "if you are 10 years old and never seen a movie before, maybe this film may be entertainment for you, but if you've seen several movies, this one will be a silly fully-cliched cheap and predictable for you. don't waste your time with this."

# %%
df.head()
# Out:
#                                               review  label
# 0  ms aparna sen, the maker of mr & mrs iyer, dir...      0
# 1  i have seen this film only once, on tv, and it...      0
# 2  i was only fourteen when i first saw the alien...      1
# 3  this marvelous short will hit home with everyo...      0
# 4  if you are 10 years old and never seen a movie...      1

# %%
df["review"] = df["review"].str.replace("<.+?/?>", "", regex=True)
xx = re.sub("<.+?/?>", "", xx)
xx
# Out:
# "if you are 10 years old and never seen a movie before, maybe this film may be entertainment for you, but if you've seen several movies, this one will be a silly fully-cliched cheap and predictable for you. don't waste your time with this."

# %%
import string

# %%
punctuation = string.punctuation
def remove_punctuation(text):
    return text.translate(str.maketrans("", "", punctuation))

df["review"] = df["review"].apply(remove_punctuation)
xx = remove_punctuation(xx)
xx
# Out:
# 'if you are 10 years old and never seen a movie before maybe this film may be entertainment for you but if youve seen several movies this one will be a silly fullycliched cheap and predictable for you dont waste your time with this'

# %%
df["review"] = df["review"].str.replace("\d+", "", regex=True)
xx = re.sub("\d+", "", xx)
xx
# Out:
# 'if you are  years old and never seen a movie before maybe this film may be entertainment for you but if youve seen several movies this one will be a silly fullycliched cheap and predictable for you dont waste your time with this'

# %%
df["review"] = df["review"].str.replace("  ", " ", regex=True)
xx = re.sub("  ", " ", xx)
xx
# Out:
# 'if you are years old and never seen a movie before maybe this film may be entertainment for you but if youve seen several movies this one will be a silly fullycliched cheap and predictable for you dont waste your time with this'

# %%
from nltk.corpus import stopwords
stopwords_str = ", ".join(stopwords.words('english'))

# %%
def remove_stopwords(text):
    new_text = []
    for token in text.split():
        if not token in stopwords_str:
            new_text.append(token)
    
    return " ".join(new_text)

# %%
df["review"] = df["review"].apply(remove_stopwords)
df["review"]
xx = remove_stopwords(xx)
xx
# Out:
# 'years old never seen movie maybe film may entertainment youve seen several movies one silly fullycliched cheap predictable dont waste time'

# %%
def remove_non_alpha(text: str):
    new_text = []
    for token in text.split():
        if token.isalpha():
            new_text.append(token)
    
    return " ".join(new_text)

# %%
df["review"] = df["review"].apply(remove_non_alpha)
xx = remove_non_alpha(xx)
type(df["review"].values)
# Out:
# numpy.ndarray

# %%
from collections import Counter

counter = Counter()

for review in df["review"]:       
    counter.update(review.split())

counter
# Out:
# Counter({'movie': 33442,
#          'film': 29752,
#          'one': 20054,
#          'like': 15523,
#          'good': 11438,
#          'even': 9672,
#          'time': 9285,
#          'really': 9076,
#          'see': 8884,
#          'story': 8861,
#          'well': 7457,
#          'much': 7372,
#          'get': 7227,
#          'also': 7067,
#          'great': 7055,
#          'bad': 7047,
#          'people': 7014,
#          'first': 6790,
#          'dont': 6627,
#          'made': 6269,
#          'movies': 6239,
#          'films': 6074,
#          'way': 6026,
#          'make': 6021,
#          'characters': 5947,
#          'think': 5839,
#          'watch': 5356,
#          'many': 5353,
#          'seen': 5285,
#          'character': 5191,
#          'two': 5137,
#          'never': 5092,
#          'love': 4989,
#          'know': 4964,
#          'best': 4925,
#          'acting': 4872,
#          'little': 4856,
#          'plot': 4853,
#          'ever': 4695,
#          'life': 4624,
#          'show': 4615,
#          'better': 4352,
#          'still': 4318,
#          'say': 4276,
#          'man': 4217,
#          'end': 4150,
#          'scene': 4129,
#          'scenes': 4013,
#          'something': 3926,
#          'go': 3793,
#          'back': 3656,
#          'real': 3640,
#          'thing': 3586,
#          'actors': 3554,
#          'doesnt': 3550,
#          'years': 3526,
#          'didnt': 3508,
#          'watching': 3506,
#          'actually': 3339,
#          'though': 3334,
#          'funny': 3331,
#          'makes': 3324,
#          'another': 3280,
#          'look': 3278,
#          'lot': 3267,
#          'nothing': 3250,
#          'find': 3241,
#          'old': 3158,
#          'going': 3152,
#          'work': 3136,
#          'new': 3084,
#          'cant': 3052,
#          'part': 3001,
#          'every': 2982,
#          'want': 2930,
#          'director': 2896,
#          'thats': 2895,
#          'quite': 2874,
#          'pretty': 2870,
#          'cast': 2825,
#          'young': 2801,
#          'fact': 2799,
#          'got': 2781,
#          'around': 2780,
#          'horror': 2774,
#          'seems': 2748,
#          'things': 2743,
#          'take': 2721,
#          'world': 2717,
#          'give': 2703,
#          'enough': 2674,
#          'thought': 2654,
#          'ive': 2611,
#          'may': 2602,
#          'big': 2569,
#          'gets': 2567,
#          'isnt': 2558,
#          'comedy': 2540,
#          'without': 2537,
#          'right': 2527,
#          'saw': 2521,
#          'however': 2495,
#          'music': 2476,
#          'interesting': 2467,
#          'long': 2459,
#          'whole': 2455,
#          'always': 2447,
#          'least': 2439,
#          'guy': 2435,
#          'times': 2422,
#          'original': 2417,
#          'almost': 2397,
#          'come': 2397,
#          'point': 2353,
#          'series': 2351,
#          'role': 2350,
#          'script': 2343,
#          'action': 2333,
#          'done': 2330,
#          'far': 2319,
#          'feel': 2306,
#          'bit': 2304,
#          'theres': 2300,
#          'family': 2276,
#          'since': 2273,
#          'minutes': 2260,
#          'anything': 2255,
#          'probably': 2221,
#          'performance': 2184,
#          'away': 2169,
#          'last': 2168,
#          'kind': 2141,
#          'rather': 2118,
#          'worst': 2086,
#          'tv': 2076,
#          'yet': 2069,
#          'found': 2066,
#          'anyone': 2060,
#          'played': 2060,
#          'girl': 2038,
#          'fun': 2030,
#          'woman': 2011,
#          'sure': 2009,
#          'believe': 1963,
#          'making': 1948,
#          'trying': 1943,
#          'especially': 1935,
#          'shows': 1906,
#          'comes': 1898,
#          'put': 1886,
#          'dvd': 1881,
#          'place': 1877,
#          'worth': 1876,
#          'different': 1875,
#          'hard': 1869,
#          'main': 1859,
#          'course': 1855,
#          'everything': 1854,
#          'looking': 1842,
#          'day': 1814,
#          'looks': 1807,
#          'although': 1806,
#          'effects': 1793,
#          'ending': 1792,
#          'money': 1791,
#          'goes': 1776,
#          'book': 1762,
#          'watched': 1762,
#          'reason': 1760,
#          'true': 1757,
#          'wasnt': 1756,
#          'sense': 1737,
#          'said': 1732,
#          'set': 1727,
#          'three': 1725,
#          'maybe': 1723,
#          'play': 1722,
#          'special': 1709,
#          'screen': 1701,
#          'job': 1697,
#          'instead': 1690,
#          'plays': 1675,
#          'seem': 1670,
#          'takes': 1669,
#          'actor': 1667,
#          'together': 1663,
#          'idea': 1655,
#          'someone': 1645,
#          'everyone': 1641,
#          'later': 1627,
#          'seeing': 1624,
#          'version': 1620,
#          'black': 1614,
#          'left': 1613,
#          'beautiful': 1610,
#          'war': 1605,
#          'excellent': 1590,
#          'high': 1575,
#          'audience': 1567,
#          'john': 1562,
#          'shot': 1561,
#          'used': 1543,
#          'wife': 1535,
#          'youre': 1531,
#          'night': 1528,
#          'simply': 1515,
#          'fan': 1511,
#          'help': 1505,
#          'poor': 1494,
#          'completely': 1494,
#          'nice': 1492,
#          'kids': 1490,
#          'american': 1490,
#          'death': 1487,
#          'house': 1484,
#          'else': 1478,
#          'year': 1465,
#          'along': 1459,
#          'second': 1444,
#          'short': 1441,
#          'home': 1441,
#          'friends': 1439,
#          'try': 1438,
#          'men': 1425,
#          'less': 1423,
#          'read': 1419,
#          'classic': 1413,
#          'given': 1408,
#          'truly': 1407,
#          'mind': 1400,
#          'half': 1395,
#          'enjoy': 1375,
#          'production': 1370,
#          'star': 1367,
#          'dead': 1365,
#          'rest': 1364,
#          'start': 1354,
#          'father': 1351,
#          'wrong': 1347,
#          'boring': 1335,
#          'either': 1333,
#          'performances': 1332,
#          'understand': 1327,
#          'couple': 1327,
#          'school': 1322,
#          'recommend': 1320,
#          'hollywood': 1312,
#          'line': 1307,
#          'stupid': 1303,
#          'others': 1300,
#          'sex': 1300,
#          'keep': 1295,
#          'tell': 1293,
#          'came': 1292,
#          'let': 1289,
#          'women': 1287,
#          'getting': 1286,
#          'next': 1286,
#          'video': 1273,
#          'camera': 1268,
#          'awful': 1268,
#          'couldnt': 1261,
#          'lines': 1258,
#          'gives': 1257,
#          'remember': 1257,
#          'mean': 1256,
#          'name': 1252,
#          'person': 1251,
#          'budget': 1248,
#          'wonderful': 1243,
#          'moments': 1241,
#          'full': 1239,
#          'terrible': 1235,
#          'playing': 1230,
#          'perhaps': 1227,
#          'top': 1225,
#          'often': 1219,
#          'absolutely': 1218,
#          'early': 1215,
#          'perfect': 1211,
#          'definitely': 1210,
#          'small': 1208,
#          'stars': 1200,
#          'piece': 1194,
#          'case': 1190,
#          'sort': 1187,
#          'human': 1181,
#          'loved': 1180,
#          'certainly': 1180,
#          'episode': 1169,
#          'face': 1167,
#          'become': 1167,
#          'guys': 1164,
#          'lost': 1162,
#          'several': 1161,
#          'went': 1160,
#          'entire': 1158,
#          'hope': 1157,
#          'dialogue': 1154,
#          'liked': 1153,
#          'head': 1146,
#          'mother': 1140,
#          'problem': 1140,
#          'felt': 1136,
#          'finally': 1135,
#          'supposed': 1133,
#          'boy': 1132,
#          'children': 1130,
#          'shes': 1127,
#          'worse': 1123,
#          'style': 1119,
#          'laugh': 1118,
#          'friend': 1112,
#          'waste': 1101,
#          'wanted': 1100,
#          'sound': 1100,
#          'beginning': 1096,
#          'totally': 1094,
#          'evil': 1094,
#          'written': 1093,
#          'seemed': 1091,
#          'entertaining': 1090,
#          'wont': 1085,
#          'based': 1085,
#          'care': 1078,
#          'live': 1075,
#          'dark': 1074,
#          'cinema': 1070,
#          'already': 1065,
#          'becomes': 1061,
#          'yes': 1055,
#          'title': 1052,
#          'fans': 1049,
#          'guess': 1047,
#          'example': 1046,
#          'able': 1046,
#          'lives': 1042,
#          'direction': 1042,
#          'lead': 1039,
#          'picture': 1037,
#          'humor': 1037,
#          'turn': 1036,
#          'white': 1027,
#          'oh': 1025,
#          'called': 1021,
#          'drama': 1017,
#          'wants': 1006,
#          'days': 1004,
#          'final': 1003,
#          'mr': 1000,
#          'amazing': 996,
#          'horrible': 984,
#          'history': 982,
#          'gave': 982,
#          'throughout': 981,
#          'favorite': 980,
#          'fine': 978,
#          'son': 978,
#          'youll': 978,
#          'theyre': 974,
#          'despite': 971,
#          'tries': 968,
#          'girls': 965,
#          'game': 965,
#          'quality': 954,
#          'kill': 953,
#          'unfortunately': 952,
#          'behind': 950,
#          'act': 948,
#          'flick': 942,
#          'ones': 939,
#          'turns': 939,
#          'works': 929,
#          'writing': 929,
#          'michael': 927,
#          'child': 922,
#          'side': 922,
#          'parts': 921,
#          'viewer': 918,
#          'town': 918,
#          'matter': 917,
#          'enjoyed': 917,
#          'thinking': 915,
#          'group': 912,
#          'sometimes': 909,
#          'brilliant': 906,
#          'eyes': 902,
#          'killer': 901,
#          'late': 901,
#          'heart': 897,
#          'past': 897,
#          'says': 896,
#          'heard': 896,
#          'expect': 896,
#          'car': 892,
#          'directed': 888,
#          'city': 887,
#          'starts': 886,
#          'stuff': 885,
#          'feeling': 882,
#          'obviously': 879,
#          'killed': 877,
#          'run': 876,
#          'fight': 875,
#          'decent': 871,
#          'happens': 868,
#          'leave': 865,
#          'police': 863,
#          'actress': 862,
#          'art': 862,
#          'overall': 859,
#          'hand': 858,
#          'kid': 856,
#          'type': 856,
#          'wouldnt': 855,
#          'soon': 852,
#          'daughter': 852,
#          'took': 851,
#          'cannot': 849,
#          'told': 848,
#          'including': 848,
#          'looked': 842,
#          'moment': 839,
#          'stories': 836,
#          'extremely': 836,
#          'except': 836,
#          'hell': 829,
#          'genre': 829,
#          'close': 829,
#          'cool': 824,
#          'lack': 822,
#          'living': 821,
#          'save': 821,
#          'simple': 821,
#          'hour': 816,
#          'experience': 814,
#          'stop': 810,
#          'etc': 809,
#          'jokes': 808,
#          'coming': 807,
#          'chance': 807,
#          'particularly': 807,
#          'ago': 806,
#          'exactly': 805,
#          'hilarious': 805,
#          'happened': 804,
#          'complete': 802,
#          'murder': 801,
#          'strong': 800,
#          'highly': 799,
#          'david': 797,
#          'shown': 796,
#          'robert': 796,
#          'ok': 796,
#          'roles': 795,
#          'serious': 794,
#          'wonder': 789,
#          'blood': 787,
#          'obvious': 787,
#          'order': 785,
#          'huge': 783,
#          'slow': 783,
#          'annoying': 778,
#          'happen': 776,
#          'seriously': 775,
#          'saying': 775,
#          'attempt': 773,
#          'english': 772,
#          'crap': 772,
#          'across': 772,
#          'score': 770,
#          'hours': 768,
#          'please': 768,
#          'sad': 767,
#          'alone': 766,
#          'lets': 764,
#          'whose': 764,
#          'shots': 763,
#          'usually': 762,
#          'taken': 762,
#          'song': 761,
#          'reality': 760,
#          'number': 760,
#          'running': 760,
#          'violence': 757,
#          'involved': 755,
#          'hit': 754,
#          'relationship': 753,
#          'possible': 752,
#          'released': 752,
#          'opening': 747,
#          'god': 747,
#          'talent': 744,
#          'major': 744,
#          'wish': 741,
#          'today': 737,
#          'silly': 736,
#          'usual': 734,
#          'started': 734,
#          'age': 732,
#          'career': 732,
#          'voice': 732,
#          'important': 730,
#          'female': 728,
#          'call': 728,
#          'james': 727,
#          'taking': 725,
#          'none': 725,
#          'brother': 723,
#          'interest': 720,
#          'husband': 720,
#          'view': 719,
#          'known': 719,
#          'apparently': 718,
#          'somewhat': 718,
#          'due': 717,
#          'jack': 716,
#          'british': 716,
#          'finds': 716,
#          'rating': 714,
#          'knows': 713,
#          'beyond': 713,
#          'arent': 713,
#          'word': 712,
#          'mostly': 711,
#          'body': 711,
#          'turned': 705,
#          'scary': 704,
#          'words': 703,
#          'happy': 703,
#          'events': 703,
#          'talking': 701,
#          'ends': 699,
#          'hero': 698,
#          'novel': 697,
#          'upon': 696,
#          'musical': 696,
#          'local': 694,
#          'gore': 693,
#          'country': 691,
#          'opinion': 689,
#          'room': 686,
#          'cut': 685,
#          'directors': 685,
#          'power': 684,
#          'anyway': 683,
#          'change': 683,
#          'knew': 683,
#          'french': 683,
#          'disappointed': 682,
#          'tells': 681,
#          'cinematography': 679,
#          'problems': 679,
#          'whats': 678,
#          'basically': 676,
#          'space': 674,
#          'hate': 670,
#          'giving': 669,
#          'mention': 668,
#          'four': 668,
#          'miss': 668,
#          'clearly': 667,
#          'strange': 666,
#          'review': 666,
#          'ridiculous': 666,
#          'modern': 665,
#          'documentary': 663,
#          'songs': 663,
#          'sets': 663,
#          'havent': 658,
#          'cheap': 658,
#          'dialog': 657,
#          'easily': 657,
#          'five': 657,
#          'showing': 656,
#          'television': 656,
#          'level': 655,
#          'needs': 654,
#          'george': 654,
#          'single': 650,
#          'dull': 649,
#          'storyline': 648,
#          'add': 648,
#          'bunch': 648,
#          'light': 644,
#          'attention': 644,
#          'talk': 644,
#          'future': 643,
#          'whether': 643,
#          'theme': 641,
#          'ten': 641,
#          'bring': 640,
#          'supporting': 640,
#          'sequence': 640,
#          'feels': 638,
#          'soundtrack': 636,
#          'middle': 634,
#          'appears': 634,
#          'team': 634,
#          'theater': 632,
#          'surprised': 630,
#          'falls': 630,
#          'named': 630,
#          'subject': 629,
#          'certain': 629,
#          'filmed': 629,
#          'using': 627,
#          'enjoyable': 627,
#          'clear': 626,
#          'effort': 626,
#          'nearly': 626,
#          'episodes': 624,
#          'monster': 624,
#          'tried': 624,
#          'means': 624,
#          'buy': 623,
#          'among': 623,
#          'message': 622,
#          'stay': 621,
#          'deal': 621,
#          'viewers': 621,
#          'fall': 620,
#          'moving': 620,
#          'lots': 620,
#          'class': 617,
#          'working': 617,
#          'parents': 616,
#          'writer': 614,
#          'comments': 614,
#          'dr': 613,
#          'near': 613,
#          'elements': 612,
#          'king': 612,
#          'sequel': 611,
#          'release': 610,
#          'peter': 609,
#          'doubt': 607,
#          'predictable': 606,
#          'mystery': 602,
#          'leads': 601,
#          'sorry': 601,
#          'easy': 601,
#          'ways': 599,
#          'romantic': 598,
#          'actual': 598,
#          'comic': 597,
#          'suspense': 597,
#          'earth': 596,
#          'similar': 594,
#          'straight': 594,
#          'minute': 590,
#          'entertainment': 588,
#          'brought': 586,
#          'die': 586,
#          'move': 586,
#          'typical': 585,
#          'animation': 584,
#          'famous': 583,
#          'gone': 582,
#          'within': 582,
#          'forget': 582,
#          'kept': 580,
#          'youve': 579,
#          'richard': 578,
#          'whos': 578,
#          'killing': 578,
#          'general': 577,
#          'premise': 576,
#          'realistic': 576,
#          'thriller': 574,
#          'gay': 572,
#          'reviews': 571,
#          'check': 571,
#          'sit': 569,
#          'rent': 568,
#          'fantastic': 566,
#          'viewing': 566,
#          'points': 563,
#          'form': 561,
#          'greatest': 561,
#          'situation': 560,
#          'crime': 559,
#          'figure': 558,
#          'feature': 557,
#          'editing': 556,
#          'boys': 556,
#          'follow': 555,
#          'features': 555,
#          'surprise': 555,
#          'eye': 555,
#          'sister': 554,
#          'tale': 554,
#          'material': 553,
#          'somehow': 552,
#          'learn': 549,
#          'weak': 549,
#          'imagine': 548,
#          'average': 548,
#          'okay': 547,
#          'atmosphere': 546,
#          'sequences': 546,
#          'indeed': 545,
#          'hot': 545,
#          'particular': 544,
#          'expected': 543,
#          'fast': 542,
#          'rock': 542,
#          'dog': 541,
#          'memorable': 541,
#          'believable': 538,
#          'period': 537,
#          'lady': 537,
#          'begins': 537,
#          'hear': 536,
#          'previous': 534,
#          'became': 534,
#          'meets': 534,
#          'forced': 534,
#          'writers': 533,
#          'towards': 532,
#          'possibly': 532,
#          'poorly': 531,
#          'york': 531,
#          'filmmakers': 531,
#          'paul': 530,
#          'imdb': 529,
#          'emotional': 527,
#          'sexual': 526,
#          'inside': 524,
#          'tom': 523,
#          'difficult': 523,
#          'scifi': 523,
#          'red': 522,
#          'personal': 522,
#          'interested': 522,
#          'plus': 522,
#          'needed': 522,
#          'lame': 521,
#          'crew': 521,
#          'shame': 520,
#          'truth': 520,
#          'write': 519,
#          'decided': 517,
#          'superb': 517,
#          'credits': 516,
#          'comment': 515,
#          'dance': 515,
#          'island': 514,
#          'leaves': 513,
#          'masterpiece': 513,
#          'eventually': 513,
#          'hands': 511,
#          'footage': 511,
#          'realize': 510,
#          'cheesy': 510,
#          'avoid': 509,
#          'effect': 509,
#          'screenplay': 508,
#          'open': 505,
#          'box': 504,
#          'quickly': 503,
#          'oscar': 502,
#          'whatever': 502,
#          'unless': 501,
#          'street': 499,
#          'note': 497,
#          'doctor': 496,
#          'keeps': 496,
#          'meet': 496,
#          'weird': 495,
#          'free': 495,
#          'third': 495,
#          'begin': 495,
#          'question': 493,
#          'deep': 493,
#          'wait': 493,
#          'otherwise': 492,
#          'joe': 491,
#          'beauty': 490,
#          'fairly': 490,
#          'crazy': 490,
#          'male': 490,
#          'deserves': 488,
#          'reading': 488,
#          'society': 487,
#          'incredibly': 487,
#          'badly': 486,
#          'romance': 486,
#          'political': 484,
#          'ideas': 484,
#          'powerful': 483,
#          'business': 483,
#          'stand': 483,
#          'copy': 483,
#          'nature': 482,
#          'appear': 481,
#          'season': 481,
#          'forward': 480,
#          'total': 480,
#          'battle': 480,
#          'older': 480,
#          'western': 479,
#          'baby': 477,
#          'earlier': 475,
#          'pay': 475,
#          'admit': 475,
#          'acted': 475,
#          'perfectly': 475,
#          'laughs': 474,
#          'various': 474,
#          'development': 474,
#          'zombie': 474,
#          'apart': 473,
#          'background': 473,
#          'mark': 472,
#          'front': 472,
#          'portrayed': 470,
#          'manages': 469,
#          'dramatic': 468,
#          'mess': 468,
#          'rich': 467,
#          'stage': 467,
#          'america': 467,
#          'cover': 467,
#          'plenty': 466,
#          'wasted': 466,
#          'create': 465,
#          'setting': 465,
#          'worked': 465,
#          'meant': 464,
#          'unique': 463,
#          'girlfriend': 463,
#          'attempts': 463,
#          'expecting': 463,
#          'fails': 462,
#          'creepy': 461,
#          'reasons': 460,
#          'sounds': 460,
#          'following': 459,
#          'directing': 458,
#          'lee': 458,
#          'fire': 458,
#          'party': 457,
#          'break': 456,
#          'ask': 456,
#          'la': 456,
#          'missing': 456,
#          'brings': 456,
#          'members': 455,
#          'air': 455,
#          'leading': 453,
#          'recently': 452,
#          'outside': 452,
#          'present': 451,
#          'bill': 451,
#          'laughing': 448,
#          'married': 447,
#          'wrote': 445,
#          'hardly': 445,
#          'return': 445,
#          'dumb': 444,
#          'result': 444,
#          'list': 444,
#          'fighting': 444,
#          'ended': 443,
#          'decides': 443,
#          'water': 443,
#          'potential': 442,
#          'van': 441,
#          'cute': 440,
#          'escape': 440,
#          'secret': 439,
#          'large': 439,
#          'odd': 439,
#          'spent': 437,
#          'appreciate': 436,
#          'twist': 435,
#          'pace': 435,
#          'telling': 434,
#          'dream': 434,
#          'agree': 433,
#          'joke': 432,
#          'cop': 430,
#          'missed': 427,
#          'caught': 427,
#          'talented': 426,
#          'german': 426,
#          'plain': 426,
#          'social': 425,
#          'sees': 425,
#          'remake': 425,
#          'hold': 425,
#          'villain': 424,
#          'state': 424,
#          'credit': 422,
#          'success': 421,
#          'brothers': 421,
#          'force': 420,
#          'clever': 420,
#          'waiting': 419,
#          'familiar': 419,
#          'japanese': 419,
#          'moves': 418,
#          'portrayal': 417,
#          'train': 417,
#          'fantasy': 417,
#          'gun': 417,
#          'disney': 416,
#          'slightly': 416,
#          'project': 415,
#          'created': 415,
#          'visual': 415,
#          'dancing': 415,
#          'uses': 414,
#          'concept': 414,
#          'nudity': 414,
#          'convincing': 413,
#          'cartoon': 411,
#          'casting': 409,
#          'incredible': 409,
#          'public': 409,
#          'basic': 408,
#          'mentioned': 408,
#          'producers': 408,
#          'produced': 408,
#          'images': 407,
#          'christmas': 407,
#          'william': 407,
#          'suddenly': 406,
#          'biggest': 405,
#          'younger': 404,
#          'hair': 402,
#          'sadly': 401,
#          'flat': 401,
#          'neither': 400,
#          'popular': 400,
#          'considering': 399,
#          'revenge': 399,
#          'italian': 399,
#          'impossible': 398,
#          'band': 398,
#          'changed': 398,
#          'era': 397,
#          'pure': 397,
#          'successful': 397,
#          'follows': 396,
#          'value': 396,
#          'office': 396,
#          'entirely': 395,
#          'compared': 395,
#          'recent': 395,
#          'bored': 392,
#          'trash': 391,
#          'unlike': 391,
#          'consider': 390,
#          'cold': 389,
#          'fear': 389,
#          'values': 389,
#          'store': 388,
#          'barely': 388,
#          'common': 388,
#          'pointless': 387,
#          'trouble': 386,
#          'amount': 386,
#          'audiences': 385,
#          'likes': 385,
#          'kills': 385,
#          'longer': 385,
#          'intelligent': 384,
#          'ultimately': 384,
#          'singing': 384,
#          'situations': 383,
#          'decide': 382,
#          'cat': 382,
#          'recommended': 381,
#          'sexy': 381,
#          'control': 380,
#          'literally': 380,
#          'former': 380,
#          'died': 379,
#          'vampire': 379,
#          'choice': 378,
#          'tension': 378,
#          'company': 378,
#          'aside': 378,
#          'remains': 378,
#          'fit': 378,
#          'normal': 377,
#          'yeah': 377,
#          'solid': 377,
#          'violent': 377,
#          'college': 377,
#          'books': 376,
#          'positive': 376,
#          'journey': 375,
#          'photography': 375,
#          'involving': 375,
#          'standard': 374,
#          'fake': 374,
#          'honest': 374,
#          ...})

# %%
vocab = sorted([token for token in counter if counter[token] > 10])
vocab_data = "\n".join(vocab)
with open("./../artifacts/vocab.txt", "w", encoding="utf-8") as file:
    file.write(vocab_data)

len(vocab)
# Out:
# 16400

# %%
with open("./../artifacts/vocab.txt", "r", encoding="utf-8") as file2:
    vt = file2.readlines()

vt = [s.strip() for s in vt]
result = [w == v for w,v in zip(vocab, vt)]
print(vt == vocab)
print("Length Vocab:- ", len(vt))
print(len(list(filter(lambda g: g == False, result))))
# Out:
# True
# Length Vocab:-  16400
# 0

# %%
from sklearn.model_selection import train_test_split

x = df["review"]
y = df["label"]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
import numpy as np

# %%
def vectorize(dataset, vocabulary):
    vectors = []
    for tweet in dataset:
        text = np.zeros(len(vocabulary))
        
        words = tweet.split()
        for i in range(len(vocabulary)):
            if vocabulary[i] in words:
                text[i] = 1
        
        vectors.append(text)
    vectorized_list = np.asarray(vectors, dtype=np.float32)
    return vectorized_list

# %%
x_train_vectorized = vectorize(x_train, vocab)
x_test_vectorized = vectorize(x_test, vocab)

# %%
xx
# Out:
# 'years old never seen movie maybe film may entertainment youve seen several movies one silly fullycliched cheap predictable dont waste time'

# %%
x_vectorized = vectorize([xx], vocab)

# %%
len(x_train_vectorized[0])
# Out:
# 16400

# %%
y_train.value_counts()
# Out:
# label
# 0    8055
# 1    7945
# Name: count, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score

def training_scores(y_act, y_pred):
    acc = round(accuracy_score(y_act, y_pred), 3)
    pr = round(precision_score(y_act, y_pred), 3)
    rec = round(recall_score(y_act, y_pred), 3)
    f1 = round(f1_score(y_act, y_pred), 3)
    print(f'Training Scores:\n\tAccuracy = {acc}\n\tPrecision = {pr}\n\tRecall = {rec}\n\tF1-Score = {f1}')
    
def validation_scores(y_act, y_pred):
    acc = round(accuracy_score(y_act, y_pred), 3)
    pr = round(precision_score(y_act, y_pred), 3)
    rec = round(recall_score(y_act, y_pred), 3)
    f1 = round(f1_score(y_act, y_pred), 3)
    print(f'Testing Scores:\n\tAccuracy = {acc}\n\tPrecision = {pr}\n\tRecall = {rec}\n\tF1-Score = {f1}')

# %%
lr = LogisticRegression()
lr.fit(x_train_vectorized, y_train)

y_train_pred = lr.predict(x_train_vectorized)

y_test_pred = lr.predict(x_test_vectorized)

training_scores(y_train, y_train_pred)

validation_scores(y_test, y_test_pred)
# Out:
# Training Scores:
# 	Accuracy = 0.997
# 	Precision = 0.997
# 	Recall = 0.996
# 	F1-Score = 0.997
# Testing Scores:
# 	Accuracy = 0.867
# 	Precision = 0.884
# 	Recall = 0.853
# 	F1-Score = 0.868

# %%
y_test_pred
# Out:
# array([1, 1, 0, ..., 1, 1, 0], dtype=int64)

# %%
y_pred = lr.predict(np.asarray(x_vectorized))

# %%
y_pred[0]
# Out:
# 1

# %%
import re
import string

import nltk
import numpy as np
from nltk.stem import WordNetLemmatizer
from numpy import ndarray

nltk.download('stopwords')
nltk.download('wordnet')


class TextPipeline:
    def __init__(self, text):
        self.__wnl = WordNetLemmatizer()
        self.__stopwords_str = ", ".join(nltk.corpus.stopwords.words('english'))
        self.text = text

    def _preprocess(self):
        self.text = self.text.lower()
        self.text = re.sub("<.+?/?>", "", self.text)
        self.text = self.text.translate(str.maketrans("", "", string.punctuation))
        self.text = re.sub(r"\d+", "", self.text)
        self.text = re.sub(r"  ", " ", self.text)

    def _remove_stopwords(self):
        new_text = []
        for token in self.text.split():
            if not token in self.__stopwords_str:
                new_text.append(token)
        self.text = " ".join(new_text)

    def _lemmatize(self):
        new_text = []
        for word in self.text.split():
            word = self.__wnl.lemmatize(word)
            new_text.append(word)
        self.text = " ".join(new_text)

    def preprocess_text(self) -> str:
        self._preprocess()
        self._remove_stopwords()
        self._lemmatize()
        print(self.text)
        return self.text

    def vectorize_text(self) -> ndarray:
        print(self.text)
        vector_array = []
        vocab_d = pd.read_csv("./../artifacts/vocab.txt", header=None)
        vocab_d = vocab_d[0].tolist()
        print(vocab_d)
        vocab = []
        for w in vocab_d:
            try:
                vocab.append(w.strip())
            except Exception as e:
               vocab.append(str(w).strip())
        vector = np.zeros(len(vocab))
        words = self.text.split()
        for i in range(len(vocab)):
            if vocab[i] in words:
                vector[i] = 1
        print(len(vector))
        vector_array.append(vector)
        np_array = np.asarray(vector_array, dtype=np.float32)
        return np_array
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\hesha\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\hesha\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
text = "this movie has actually good script. good movie. recommended"
pipeline = TextPipeline(text)
pipeline.preprocess_text()
vector = pipeline.vectorize_text()

prediction = lr.predict(vector)
prediction
# Out:
# movie actually good script good movie recommended
# movie actually good script good movie recommended
# ['aag', 'aamir', 'aardman', 'aaron', 'abandon', 'abandoned', 'abandoning', 'abandonment', 'abandons', 'abba', 'abbey', 'abbot', 'abbott', 'abc', 'abducted', 'abduction', 'abe', 'abel', 'abhay', 'abigail', 'abilities', 'ability', 'able', 'ably', 'abnormal', 'aboard', 'abominable', 'abomination', 'aboriginal', 'aborted', 'abortion', 'abound', 'aboutthe', 'aboveaverage', 'abraham', 'abroad', 'abrupt', 'abruptly', 'absence', 'absent', 'absolute', 'absolutely', 'absorb', 'absorbed', 'absorbing', 'abstract', 'absurd', 'absurdist', 'absurdities', 'absurdity', 'absurdly', 'abu', 'abundance', 'abundant', 'abuse', 'abused', 'abusing', 'abusive', 'abysmal', 'abyss', 'academic', 'academy', 'accent', 'accented', 'accents', 'accept', 'acceptable', 'acceptance', 'accepted', 'accepting', 'accepts', 'access', 'accessible', 'accident', 'accidental', 'accidentally', 'accidents', 'acclaim', 'acclaimed', 'accolades', 'accompanied', 'accompanies', 'accompaniment', 'accompany', 'accompanying', 'accomplice', 'accomplish', 'accomplished', 'accomplishes', 'accomplishment', 'according', 'accordingly', 'account', 'accountant', 'accounts', 'accuracy', 'accurate', 'accurately', 'accusations', 'accuse', 'accused', 'accuses', 'accustomed', 'ace', 'achieve', 'achieved', 'achievement', 'achievements', 'achieves', 'achieving', 'achilles', 'aching', 'achingly', 'acid', 'ackland', 'acknowledge', 'acknowledged', 'acquaintance', 'acquaintances', 'acquainted', 'acquire', 'acquired', 'acre', 'acres', 'acrobatics', 'across', 'act', 'acted', 'acting', 'actingthe', 'action', 'actionadventure', 'actioner', 'actionpacked', 'actions', 'active', 'actively', 'activist', 'activists', 'activities', 'activity', 'actor', 'actoractress', 'actors', 'actorsactresses', 'actorsthe', 'actress', 'actresses', 'acts', 'actual', 'actuality', 'actually', 'ada', 'adam', 'adams', 'adamson', 'adapt', 'adaptation', 'adaptations', 'adapted', 'adapting', 'adaption', 'add', 'added', 'addict', 'addicted', 'addiction', 'addictive', 'addicts', 'adding', 'addition', 'additional', 'additionally', 'additions', 'address', 'addressed', 'addresses', 'addressing', 'adds', 'adelaide', 'adele', 'adept', 'adequate', 'adequately', 'aditya', 'adjani', 'adjective', 'adjectives', 'adjust', 'administration', 'admirable', 'admirably', 'admiral', 'admiration', 'admire', 'admired', 'admirer', 'admirers', 'admires', 'admiring', 'admission', 'admit', 'admits', 'admitted', 'admittedly', 'admitting', 'adolescence', 'adolescent', 'adolf', 'adopt', 'adopted', 'adoption', 'adoptive', 'adopts', 'adorable', 'adore', 'adored', 'adores', 'adrenaline', 'adrian', 'adrienne', 'ads', 'adult', 'adulterous', 'adultery', 'adulthood', 'adults', 'adv', 'advance', 'advanced', 'advancement', 'advances', 'advancing', 'advantage', 'advent', 'adventure', 'adventurer', 'adventures', 'adventurous', 'adversaries', 'adversity', 'advert', 'advertised', 'advertisement', 'advertisements', 'advertising', 'advice', 'advise', 'advised', 'adviser', 'advocate', 'aerial', 'aesthetic', 'aesthetically', 'aesthetics', 'afar', 'affable', 'affair', 'affairs', 'affect', 'affected', 'affecting', 'affection', 'affectionate', 'affections', 'affects', 'affleck', 'afflicted', 'affluent', 'afford', 'afghan', 'afghanistan', 'aficionado', 'aficionados', 'afloat', 'aforementioned', 'afraid', 'africa', 'african', 'africanamerican', 'africans', 'afroreggae', 'afterlife', 'aftermath', 'afternoon', 'afterthought', 'afterward', 'afterwards', 'afterwords', 'againthe', 'agatha', 'age', 'aged', 'ageing', 'agencies', 'agency', 'agenda', 'agendas', 'agent', 'agents', 'ages', 'aggression', 'aggressive', 'aging', 'agnes', 'ago', 'agonizing', 'agonizingly', 'agony', 'agree', 'agreed', 'agreeing', 'agreement', 'agrees', 'ah', 'ahead', 'ahem', 'aid', 'aided', 'aiden', 'aids', 'ailing', 'aim', 'aimed', 'aiming', 'aimless', 'aimlessly', 'aims', 'aint', 'air', 'aircraft', 'aired', 'airhead', 'airing', 'airline', 'airplane', 'airplanes', 'airport', 'airs', 'ajay', 'aka', 'akin', 'akira', ...
# 16400
# array([0], dtype=int64)

# %%
import pickle

with open('./../artifacts/model.pickle', 'wb') as file:
    pickle.dump(lr, file)

# %%
tt = vector == x_vectorized
tt.all()
# Out:
# False

# %%
punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
'jjsdf–' in punctuation
# Out:
# False

# %%
'jjsdf–'.isalnum()
# Out:
# False
